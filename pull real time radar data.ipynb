# %%
import requests
from PIL import Image

# %%
url = "https://www.dwd.de/DWD/wetter/radar/rad_brd_akt.jpg"

# %%
Image.open(requests.get(url, stream=True).raw)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x500 at 0x19EA05F6848>
